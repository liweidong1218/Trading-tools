# %%
import datetime
import numpy as np
import pandas as pd
import mplfinance as mpf

# %%
import os
import shutil
import sys
from time import time
from uuid import uuid4
from workers import *
from taFunc import *

# %%
ticker = 'AAPL'
start = '2000-01-01'
end = '2021-07-13'

# %%
def file_processor(ticker, start, end):
    print('Pulling market data for {} from {} to {}.'.format(ticker, start, end))
    d = get_all_price(ticker, start, end)
    # d = pd.read_table(data_file, sep=',', header=None, index_col=0, names=['Price', 'Volume'])
    # d.index = d.index.map(lambda ts: datetime.datetime.fromtimestamp(int(ts)))
    # d.index.names = ['DateTime_UTC']
    # p = pd.DataFrame(d['Price'].resample('5Min').ohlc())
    d.columns = [s.capitalize() for s in d.columns.to_list()]

    d['ma_8'] = d['Adj close'].rolling(8).mean()
    d['ma_20'] = d['Adj close'].rolling(20).mean()
    d['ma_50'] = d['Adj close'].rolling(50).mean()
    d['ma_200'] = d['Adj close'].rolling(200).mean()

    d['RSI'] = get_rsi(d['Adj close'], 14, fill_na = True)

    d = d.dropna()
    # d.to_csv('{}_{}_{}.csv'.format(ticker, start, end), sep=',')
    return d

# %%
def compute_returns(p):
    close_prices = p['Close']
    close_prices_returns = 100 * ((close_prices.shift(-1) - close_prices) / close_prices).fillna(0.0)
    return close_prices_returns.shift(1).fillna(0)

# def plot_p(df):
#     import matplotlib.pyplot as plt
#     import mplfinance as mpf
#     mpf.plot(df,type='candle')
#     print('Done.')


def save_to_file(df, filename):
    import matplotlib.pyplot as plt
    import mplfinance as mpf
    plot_df = df[['Open', 'High', 'Low', 'Close', 'Adj close', 'Volume']].copy()
    # adps = [mpf.make_addplot(df[['ma_8', 'ma_20', 'ma_50', 'ma_200']].copy()), 
    #         mpf.make_addplot(df[['RSI']].copy())
    #         ]
    adps = [mpf.make_addplot(df[['ma_8']], color = 'green'),
            mpf.make_addplot(df[['ma_50']], color = 'red'), 
            mpf.make_addplot(df[['RSI']], color = 'purple', panel = 1)
            ]
    
    mpf.plot(plot_df, addplot=adps, type='candle', axisoff=True, volume=True, savefig=dict(fname=filename, dpi=50, pad_inches=0))
    

def mkdir_p(path):
    import os
    import errno
    try:
        os.makedirs(path)
    except OSError as exc:
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

# %%
def add_returns_in_place(df):  # modifies df
    close_prices_returns = compute_returns(df)
    num_bins = 10
    returns_bins = pd.qcut(close_prices_returns, num_bins)
    bins_categories = returns_bins.values.categories
    returns_labels = pd.qcut(close_prices_returns, num_bins, labels=False)

    df['close_price_returns'] = close_prices_returns
    df['close_price_returns_bins'] = returns_bins
    df['close_price_returns_labels'] = returns_labels

    return df, bins_categories

# %%
# def generate_quantiles(data_folder, bitcoin_file):
#     def get_label(btc_df, btc_slice, i, slice_size):
#         class_name = str(btc_df[i + slice_size:i + slice_size + 1]['close_price_returns_labels'].values[0])
#         return class_name

#     return generate_cnn_dataset(data_folder, bitcoin_file, get_label)


def generate_up_down(data_folder, ticker, start, end):
    def get_price_direction(df, df_slice, i, slice_size):
        # last_price = btc_slice[-2:-1]['price_close'].values[0] #this is actually the second last price
        last_price = df_slice[-1:]['Close'].values[0] #one option to get the correct last price
        # last_price = btc_df[i + slice_size - 1:i + slice_size]['price_close'].values[0] #another option to get the correct last price

        next_price = df[i + slice_size:i + slice_size + 1]['Close'].values[0]
        if last_price < next_price:
            class_name = 'UP'
        else:
            class_name = 'DOWN'
        return class_name

    return generate_cnn_dataset(data_folder, ticker, start, end, get_price_direction)

# %%
def generate_cnn_dataset(data_folder, ticker, start, end, get_class_name):
    df = file_processor(ticker, start, end)
    df, levels = add_returns_in_place(df)

    print('-' * 80)
    print('Those values should be roughly equal to 1/len(levels):')
    for ii in range(len(levels)):
        print(ii, np.mean((df['close_price_returns_labels'] == ii).values))
    print(levels)
    print('-' * 80)

    slice_size = 20 # 40 day window
    test_every_steps = 10
    n = len(df) - slice_size

    shutil.rmtree(data_folder, ignore_errors=True)
    for epoch in range(int(4000)):
        st = time()

        i = np.random.choice(n, replace = False) # randomly sampling window withou replacement
        df_slice = df[i:i + slice_size]

        if df_slice.isnull().values.any():
            # sometimes prices are discontinuous and nothing happened in one 5min bucket.
            # in that case, we consider this slice as wrong and we raise an exception.
            # it's likely to happen at the beginning of the data set where the volumes are low.
            raise Exception('NaN values detected. Please remove them.')

        class_name = get_class_name(df, df_slice, i, slice_size)
        save_dir = os.path.join(data_folder, 'train', class_name)
        if epoch % test_every_steps == 0:
            save_dir = os.path.join(data_folder, 'test', class_name)
        mkdir_p(save_dir)
        filename = save_dir + '/' + str(uuid4()) + '.png'
        save_to_file(df_slice, filename=filename)
        print('epoch = {0}, time = {1:.3f}, filename = {2}'.format(str(epoch).zfill(8), time() - st, filename))

# %%
data_folder = r'D:\Git Repository\_local_data_\DLW\TA CNN'

# %%
use_quantiles = None

data_gen_func = generate_quantiles if use_quantiles else generate_up_down
print('Using: {}'.format(data_gen_func))
data_gen_func(data_folder, ticker, start, end)
# Out:
# Using: <function generate_up_down at 0x00000262A97B0DC0>
# Pulling market data for AAPL from 2000-01-01 to 2021-07-13.
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------------------------------------
# Those values should be roughly equal to 1/len(levels):
# 0 0.10007668711656442
# 1 0.10007668711656442
# 2 0.09988496932515338
# 3 0.10007668711656442
# 4 0.09988496932515338
# 5 0.10007668711656442
# 6 0.09988496932515338
# 7 0.10007668711656442
# 8 0.09988496932515338
# 9 0.10007668711656442
# IntervalIndex([(-17.921000000000003, -2.402], (-2.402, -1.323], (-1.323, -0.694], (-0.694, -0.28], (-0.28, 0.0891], (0.0891, 0.508], (0.508, 0.989], (0.989, 1.588], (1.588, 2.683], (2.683, 13.905]], dtype='interval[float64, right]')
# --------------------------------------------------------------------------------
# epoch = 00000000, time = 0.105, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/a7fbe330-1a6d-412f-bdee-1449f1e01a72.png
# C:\Users\liwei\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# epoch = 00000001, time = 0.116, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/66d1044a-018d-46ba-b3c0-89d8a31a1702.png
# epoch = 00000002, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1eb1e41c-95b7-4568-94ff-3ae05d5d6b42.png
# epoch = 00000003, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/df7539c8-1a93-4ab9-b710-a03884537861.png
# epoch = 00000004, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/70d37263-388f-4fdc-8ccd-f7eb62e5dc66.png
# epoch = 00000005, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/7e8c707b-98a8-4752-9374-6450423366ca.png
# epoch = 00000006, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/46627474-a43b-4a3d-a192-69a47e0240bb.png
# epoch = 00000007, time = 0.123, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b1e8cb8a-9509-4949-88e2-28114df83eb7.png
# epoch = 00000008, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cbd84f2a-1f30-4bd5-91d9-a5d09ac075cc.png
# epoch = 00000009, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/babdaf61-ad99-4c6e-afd5-54b387d0df39.png
# epoch = 00000010, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/d5350b4c-7a71-430f-9f6f-9ec6eaa13f66.png
# epoch = 00000011, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/7ee53d80-ce8c-45e1-b792-767bdfec3164.png
# epoch = 00000012, time = 0.143, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/78bfa51b-fde3-426e-b108-5a483f2e5261.png
# epoch = 00000013, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/48bf2b1f-6bb3-4357-ab93-886385e791d3.png
# epoch = 00000014, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/31efb8db-98a1-4654-b13d-218a29dc21d9.png
# epoch = 00000015, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e04fdd8f-e33f-4cb9-862f-9cb65e35906a.png
# epoch = 00000016, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/8d229789-e11e-48b7-8cb6-29928a953cde.png
# epoch = 00000017, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/2bf917e8-f352-42f1-a6d8-46066fa42cc1.png
# epoch = 00000018, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0a6df292-cf42-4da6-bede-10f5e040516d.png
# epoch = 00000019, time = 0.148, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a1f1e4d2-2442-419f-9e1f-e8c102a20786.png
# epoch = 00000020, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/958ad0ac-ee8b-4292-bd98-88634cce6191.png
# epoch = 00000021, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/99b33080-408e-474f-b0ec-db9c3427d874.png
# epoch = 00000022, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b963aea0-ffd5-4abc-b8c0-3271ae12b435.png
# epoch = 00000023, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/703fd30c-ef54-4cd3-b419-50c69a21311f.png
# epoch = 00000024, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e130cc22-0ab1-4ac3-ae29-05e01fb4da6a.png
# epoch = 00000025, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6798211c-83b5-4701-9e84-c063b3ab9642.png
# epoch = 00000026, time = 0.170, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e74feb11-1589-471b-b9a4-2b2a91a1fbc1.png
# epoch = 00000027, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/86663406-2ea1-43b4-a1f6-1c9dab8047bc.png
# epoch = 00000028, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/9f992644-263e-4c7b-ab43-bd981f1228cd.png
# epoch = 00000029, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ba47336b-e60f-4ed1-819f-287a2bcbba91.png
# epoch = 00000030, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/d45a882e-bf0d-4d39-8639-c072d5cb1698.png
# epoch = 00000031, time = 0.089, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f261e81a-ed6f-425d-8d1a-a4217fff9d53.png
# epoch = 00000032, time = 0.089, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/7301861a-b41d-4727-a108-c5cc84a2ffcf.png
# epoch = 00000033, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/25328359-8388-4727-a81b-ebedb8fafdd7.png
# epoch = 00000034, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/07fb1a89-a1ae-45b4-bf2f-f1b73d8c10b3.png
# epoch = 00000035, time = 0.090, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/7a644a7a-2099-448d-bfd8-669897ee2185.png
# epoch = 00000036, time = 0.186, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c0e57fee-afd7-45ad-9027-eb7b2ff4ed6a.png
# epoch = 00000037, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ab139623-a462-4b5d-8174-6c45350c4b71.png
# epoch = 00000038, time = 0.089, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/be6c2c0d-863d-413c-bd2b-0f2ad1d280b5.png
# epoch = 00000039, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN
time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/8a338d1d-6cf5-4f66-ab33-947fd6f200ed.png
# epoch = 00000077, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/aafe927c-d1ac-4063-b71f-fa1815fa9d04.png
# epoch = 00000078, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6cac18e2-ff9a-415c-87f4-0c88b24f0847.png
# epoch = 00000079, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/3fa02205-dc1f-4db2-b07e-4a82c2142979.png
# epoch = 00000080, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/11a792ad-df77-4cb6-a2fc-dbacaaca7235.png
# epoch = 00000081, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/857e297c-50c8-4d46-831e-f88f3176a3cc.png
# epoch = 00000082, time = 0.312, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e858a596-ef0e-42c2-8350-12ef5cea15a4.png
# epoch = 00000083, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/77b0aafa-45e8-4594-952d-94bfe05aa96d.png
# epoch = 00000084, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0dc088d7-fea7-46be-82b8-58e6a21f1929.png
# epoch = 00000085, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6c444213-9137-45dd-b7a2-679fd5de4ad2.png
# epoch = 00000086, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/a66605b3-733f-41c1-8fc2-dda99ec73850.png
# epoch = 00000087, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/06f62ece-25cf-4516-adad-d72ba332116e.png
# epoch = 00000088, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ae07139d-5d92-4db8-841d-4c98dc4ca2a3.png
# epoch = 00000089, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/3838ac7b-5fdd-4201-8e1a-bf8097441e16.png
# epoch = 00000090, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/fe342118-9012-4630-b983-fa961ea66467.png
# epoch = 00000091, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/eddcf8ab-9019-43df-b19d-bae18b942359.png
# epoch = 00000092, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ac5ba400-fb8c-472e-be8e-e3871b3dcedc.png
# epoch = 00000093, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/4e9acfdf-739b-4d21-b3f5-dcbbf9659537.png
# epoch = 00000094, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ff4229b0-a919-4ad1-93d4-957c252e4536.png
# epoch = 00000095, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/31044602-a2f1-48c2-b668-0e1ed975df5f.png
# epoch = 00000096, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/12c2707e-6abb-405f-be2d-e2cc9c15ac0a.png
# epoch = 00000097, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/80b333cb-a1a2-46a2-ad6b-8563caa74297.png
# epoch = 00000098, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/686b21ac-1d6f-4f29-80e0-145b098b2129.png
# epoch = 00000099, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/089f8a59-bb12-405a-a546-d77bb01c4da7.png
# epoch = 00000100, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/1fabada9-dee6-4213-841e-3c39f2126321.png
# epoch = 00000101, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/588d11c2-e364-4121-8718-25ca42cb1489.png
# epoch = 00000102, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/c5f6dbe9-689c-41fe-8412-84575e9d6f9f.png
# epoch = 00000103, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c8201679-b0f1-4840-815a-c9aafc2ad0b7.png
# epoch = 00000104, time = 0.352, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/5cd2748e-a9e5-47f0-84cc-4e4fbc8e54c2.png
# epoch = 00000105, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e4880a4b-1572-4fa3-adc4-8053453ba25a.png
# epoch = 00000106, time = 0.091, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f8f246ea-c988-4809-ba6f-26afc891baf6.png
# epoch = 00000107, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/4245dd77-4bd0-4d6b-810a-cb235bbbb1d8.png
# epoch = 00000108, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/9cc96601-7a1d-4e29-ab93-73b830968a91.png
# epoch = 00000109, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a949c21c-21d0-4423-a149-a3c7d3bd6c5b.png
# epoch = 00000110, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/bee41fab-6089-49de-a5b7-64c37c91fc59.png
# epoch = 00000111, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/fb0ddb78-f7f7-44b4-96a5-609e277f2b5a.png
# epoch = 00000112, time = 0.092, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP
time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/a2feddbb-8b16-49de-ae11-7a463dc05817.png
# epoch = 00000150, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/dc049184-4b5b-4ab3-856b-913457c77bbf.png
# epoch = 00000151, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/728adeb1-bc2d-4982-96a1-b2940a7ac1ed.png
# epoch = 00000152, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c7206202-768d-412f-8646-e00216687658.png
# epoch = 00000153, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/5eecf00a-117a-4f6e-99c3-a3c2aafba89d.png
# epoch = 00000154, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/747e3f0f-e380-448f-b262-7ba1bad32ad8.png
# epoch = 00000155, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b421dd30-ea45-49c7-9ef8-e957ceb6bc9f.png
# epoch = 00000156, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c7eb5793-9976-450f-8910-ae21909f224c.png
# epoch = 00000157, time = 0.093, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e990cc2c-9549-4a1c-8b60-9b5be3d5617e.png
# epoch = 00000158, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/4b6ab49a-94a5-48e3-8968-9c5cac3e318a.png
# epoch = 00000159, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e0bbf1e2-2fee-4037-b5d1-bc9aa1326d97.png
# epoch = 00000160, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/3404e290-546c-4566-a376-0dc846ce1d80.png
# epoch = 00000161, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6d88b9a8-a1e4-41dd-a693-ca5ef175498b.png
# epoch = 00000162, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/da46a6f1-6303-4f6b-9ea7-a0bd77d3db42.png
# epoch = 00000163, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1bb6cd54-d55a-4cb5-8485-f8f5bc99111a.png
# epoch = 00000164, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/4a0b9711-e295-4039-9e63-0f284ed2c2fc.png
# epoch = 00000165, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/cf416b8e-1dab-4d59-8946-8553a5e8c514.png
# epoch = 00000166, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ed33a786-c4e8-4818-8fa9-736e55b166c9.png
# epoch = 00000167, time = 0.506, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/81921e3f-419a-4957-a1d4-9ff22a50dad8.png
# epoch = 00000168, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/75e4217b-6e60-4045-af97-21e4e6c21501.png
# epoch = 00000169, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/bbb4d4e7-bce7-4266-8a4c-978503f1cedd.png
# epoch = 00000170, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/620b8df4-5fa9-4ecf-9327-306fe785c559.png
# epoch = 00000171, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/c4d630ef-43e6-41e9-9c93-e63297875026.png
# epoch = 00000172, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b27c170f-0046-4ad9-8b03-cc39c1692e67.png
# epoch = 00000173, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c7579583-6145-4cb0-b2f2-f1f2b61eb113.png
# epoch = 00000174, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/9df0b351-ecd5-4167-91a0-d8edd1987e16.png
# epoch = 00000175, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/806f65a1-1291-4b42-bc3b-e931128f941d.png
# epoch = 00000176, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/4cae2edd-6b59-44cd-9617-5f66e58f18f6.png
# epoch = 00000177, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/704e2d43-eb1f-474e-985e-7340de0434bd.png
# epoch = 00000178, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e16a03a4-cc6a-4590-81fd-c18a573c7fa4.png
# epoch = 00000179, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b9acefdd-937a-4663-b889-cfbc8bc544e3.png
# epoch = 00000180, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/ad298685-eda6-4006-a12a-18f8c3fb6673.png
# epoch = 00000181, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/5fde01dd-d644-4611-935b-0e71b60c20e9.png
# epoch = 00000182, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6c3edb45-2134-4a95-a1a8-c3a09686e143.png
# epoch = 00000183, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/76fe093e-8320-4c23-b99e-8fb316ac0d33.png
# epoch = 00000184, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e9473829-7078-4936-8aef-9be3c28dcfed.png
# epoch = 00000185, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/b5ee8ff8-ee9b-4e3c-9705-1566a0c9ed0a.png
# epoch = 00000186, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/3f0e9709-644f-423d-96cb-b5eedb115ebe.png
# epoch = 00000187, time = 0.094, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cd16c02a-1c24-43f5-80d9-4756c32a558d.png
# epoch = 00000188, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/028c465b-b0ee-49af-811e-a08d13f5dd7e.png
# epoch = 00000189, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/f2ddd024-2662-4210-a2d0-c6013211aac6.png
# epoch = 00000190, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/290e8207-cf2f-4289-a738-5320ba2ad337.png
# epoch = 00000191, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f54b5c3b-1b9a-4fec-8916-ab556e778fb9.png
# epoch = 00000192, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/09edabb4-1aca-4f8c-a802-a136c2d5f47a.png
# epoch = 00000193, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/2fef4bb2-67f3-4562-90a2-45419c2e1dc1.png
# epoch = 00000194, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a3b08814-955a-449b-9214-e5aa15279008.png
# epoch = 00000195, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ddd8af8b-37d0-46ce-8258-3a3369ad12a8.png
# epoch = 00000196, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b92aed1e-5417-4466-a861-e51866063a68.png
# epoch = 00000197, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/2b5523b5-1496-4f6c-a242-2bd4c145c614.png
# epoch = 00000198, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/48c9bc8a-6bf1-48c9-9939-c9222d0a96f5.png
# epoch = 00000199, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e78fc15d-99d6-4560-a4ce-39e0d2828f3a.png
# epoch = 00000200, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/b1a2a99e-2984-43b2-b476-9ea0dc528200.png
# epoch = 00000201, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/081782de-f977-4276-a02c-9a323cb122d1.png
# epoch = 00000202, time = 0.095, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/8be577de-50a3-40e4-9003-f0f8e2efab88.png
# epoch = 00000203, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/7ffd3b30-b008-46e6-af06-acc55df0d8e1.png
# epoch = 00000204, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6313b9a8-77c1-41f6-965c-30f6c15e860b.png
# epoch = 00000205, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/9fe4d5c9-f108-473c-87ca-9d9243501274.png
# epoch = 00000206, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/2e61ccbe-84d0-4525-b4d9-cb588bf7c8e3.png
# epoch = 00000207, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cde2eb97-f21b-45c0-993d-8ad5a29b5c78.png
# epoch = 00000208, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cd9865bc-dc15-4c9f-ae5f-a8aa4b4c4df0.png
# epoch = 00000209, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6c63b5ff-cd02-400f-a83e-c40f4e7b612d.png
# epoch = 00000210, time = 0.652, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/81a761be-1f42-41e9-90ef-936502d0e507.png
# epoch = 00000211, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c307b756-a856-40e5-ae4f-319e991672ee.png
# epoch = 00000212, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ad4cec1c-4c88-4aa7-ba78-535458f111c2.png
# epoch = 00000213, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/2ac9192f-c89e-4b3a-a0db-e097e9f7025d.png
# epoch = 00000214, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/b1fa4e33-4d17-48ab-9f31-a354f7378a9c.png
# epoch = 00000215, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/1d8e88f0-b606-49d3-bb14-99b39b567ecb.png
# epoch = 00000216, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e8223c2f-071b-49a7-86b4-d86638e3253d.png
# epoch = 00000217, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/d68bea71-fc22-46c9-a4e2-4e1858146f25.png
# epoch = 00000218, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/9619088e-1cfd-4c82-a25c-942b3e62fd31.png
# epoch = 00000219, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/4cbac452-6b15-4ffd-915c-8889d1ed72b5.png
# epoch = 00000220, time = 0.096, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/b6582028-d6fb-4cce-887a-8bfa08fe33de.png
# epoch = 00000221, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/1f2945a2-0078-4b87-99cd-d822b68bddae.png
# epoch = 00000222, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/49091252-ee0e-462b-b8b4-7dde08d8977f.png
# epoch = 00000223, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP
time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/cb8e2609-baab-4800-b4b6-245552e8a588.png
# epoch = 00000261, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/573ff133-a1d3-436d-bb47-aba26649065b.png
# epoch = 00000262, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/5a5372aa-bfbe-4c0c-8fa3-22b281fa6a9c.png
# epoch = 00000263, time = 0.104, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/d680c912-d3f2-4aa8-9106-701fadbaaaef.png
# epoch = 00000264, time = 0.789, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1d1cbd57-431d-4899-837c-c3ffc81dfdf9.png
# epoch = 00000265, time = 0.097, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ae22b87d-e98f-4bfe-8d67-bbc178a1f8d8.png
# epoch = 00000266, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/95cbc428-7ab8-48e7-99ff-f07ea3b2d8eb.png
# epoch = 00000267, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/949ceb17-5ce7-435f-b7b0-f5e7320f3963.png
# epoch = 00000268, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/637a31f3-8954-4faa-9f9d-febdc59f8e15.png
# epoch = 00000269, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/2a00f603-07f7-4c8a-90a4-466be138d107.png
# epoch = 00000270, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/384c1a03-781d-446e-9131-65c1ed096943.png
# epoch = 00000271, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/8ea04515-2d43-4b76-b057-2ba17ebf5093.png
# epoch = 00000272, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/fd79042a-878f-45b5-9d6e-cb256c4c54da.png
# epoch = 00000273, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/a2548d17-c06a-4c66-a417-3591bbac5770.png
# epoch = 00000274, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0ec771fa-e132-4b70-abe5-4693e98c8149.png
# epoch = 00000275, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/cb3ed8c6-ab1d-4c10-b9bb-387bae6be7c4.png
# epoch = 00000276, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/23e72d5f-8e97-4c7f-91ea-8781d089f553.png
# epoch = 00000277, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c17382aa-80f2-4b45-a5ac-7ff153dd2d11.png
# epoch = 00000278, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/4b4c0261-9cdf-4f02-977e-645486a4a1d5.png
# epoch = 00000279, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/e3e98fa5-065e-4d51-b0d8-bd46e4c0baca.png
# epoch = 00000280, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/199a45e0-f474-47a5-bcd9-a29ad163227e.png
# epoch = 00000281, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/c30a5b4f-9026-4600-a0c7-49cbfb2bbb27.png
# epoch = 00000282, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/10e87347-28dd-4d11-9bc7-8140fb174745.png
# epoch = 00000283, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/37b4989d-eb45-4f6b-92d6-d5176e5c43fe.png
# epoch = 00000284, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e721b696-127b-4d39-aebf-d7696255a012.png
# epoch = 00000285, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/180181ca-bb11-409b-85f5-08f95301f893.png
# epoch = 00000286, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cf2c0b85-6f33-438f-aaad-0322b8a70f6b.png
# epoch = 00000287, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ec80d12a-8361-45f8-a7e8-db6c71399c41.png
# epoch = 00000288, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/d806d497-1d1f-4274-aa7e-80c71c469cbc.png
# epoch = 00000289, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/30abdaed-2eba-4f49-b0fa-f105baffebcc.png
# epoch = 00000290, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/15e943c9-acd1-46a3-830b-6fb6ed9fb30b.png
# epoch = 00000291, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ce2860e5-bd30-430e-b616-da841e8bc566.png
# epoch = 00000292, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/41ce3fee-f7f1-49ed-84a7-c53a8361ce92.png
# epoch = 00000293, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/fce8e265-b433-4b2d-9eff-9def78bd1c2f.png
# epoch = 00000294, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/c2ca5c3e-b252-40ce-9136-66eca454aacb.png
# epoch = 00000295, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b2307292-2100-4fa0-9e78-bc4de99e6d0f.png
# epoch = 00000296, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/8c525199-f04a-4724-8b8b-0cd02bc16bb4.png
# epoch = 00000297, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0afdb740-46c6-415a-8ecd-9c2ed179ee46.png
# epoch = 00000298, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cdef8c26-5154-4a1c-b1c9-eb7f3bb39146.png
# epoch = 00000299, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/d52474d5-8b34-4390-9d6e-83fbaba73c03.png
# epoch = 00000300, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/e16e8e8f-69aa-4dfa-b9be-6233ddf1bf59.png
# epoch = 00000301, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/da306c01-3df9-42d0-803d-f0db55074905.png
# epoch = 00000302, time = 0.099, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/72ec843c-3bc0-4adb-ab36-d90341a64384.png
# epoch = 00000303, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/0b00e88c-174a-40f0-95e3-5d1342166505.png
# epoch = 00000304, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/dcfec55e-153e-4674-9f02-6c0e26ae07e4.png
# epoch = 00000305, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/fb550448-2bf5-4843-b803-6e1cfc368a0a.png
# epoch = 00000306, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/11d6fd64-a96f-430e-b759-8c34600f787e.png
# epoch = 00000307, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f35c3302-3745-44d3-b793-a52bdf08e37e.png
# epoch = 00000308, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6cc5b968-3572-4a81-83aa-d4f95d467387.png
# epoch = 00000309, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ffb3ab00-5e61-4c30-a7f8-177bb510a278.png
# epoch = 00000310, time = 0.098, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/371e983c-2375-41ae-b7e3-cc7b1630c68d.png
# epoch = 00000311, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/58e4d16f-dc40-4ca9-9d28-31b4d7f9f31a.png
# epoch = 00000312, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/900d0318-64e6-4f3c-9540-383af309e2f5.png
# epoch = 00000313, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e8c38627-ee5c-4b9a-a885-cfef863b0614.png
# epoch = 00000314, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/163c22e0-6422-43f7-acb0-dac462940b4f.png
# epoch = 00000315, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6455e468-d09d-4155-b6b3-3eb18ccc4b79.png
# epoch = 00000316, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a23e22da-41a8-4d0e-97b3-73721bfa0a93.png
# epoch = 00000317, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/24c1a17a-94ae-4dc6-8956-964268fc48ee.png
# epoch = 00000318, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/741c4601-ef27-49bd-bd42-02e64fb3264a.png
# epoch = 00000319, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/fdc2dd2c-38d3-4c44-8be9-6244b48b5ad4.png
# epoch = 00000320, time = 0.107, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/e04cf4da-3772-437d-8f33-16da1015c54d.png
# epoch = 00000321, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/49e5cac2-d717-4390-b076-18442a707b3d.png
# epoch = 00000322, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1451b2e9-0dc4-4023-890e-d7cbba4ae413.png
# epoch = 00000323, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/5f1ba29e-d825-48c4-b785-4f42be31479a.png
# epoch = 00000324, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/739a2615-3a9c-487b-a952-09a1bbded079.png
# epoch = 00000325, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/09468b4d-0b16-4c4b-aea1-8ccecc95d85a.png
# epoch = 00000326, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ec01a7b6-5668-4f70-b502-c5380b6fa6a4.png
# epoch = 00000327, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/2047ae9f-c00c-4ff6-a9f9-d1275a0bdb22.png
# epoch = 00000328, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6577ef3d-2a22-425b-b509-18e4861c0935.png
# epoch = 00000329, time = 0.983, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/48425250-ddd4-487e-affe-8c84392b72d1.png
# epoch = 00000330, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/d618dc42-cbe2-4eca-8f29-654b4a80561e.png
# epoch = 00000331, time = 0.100, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/8f52b943-1e1e-49b9-9919-e9745abddda1.png
# epoch = 00000332, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f0ed600a-ad84-4421-9059-91c5b31e9323.png
# epoch = 00000333, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/850e8bb9-160d-42e1-96d9-d9104a5019fb.png
# epoch = 00000334, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/3fbc8113-d48b-496f-a940-ea82511e347f.png
# epoch = 00000335, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c19336db-c4d3-414e-a7f8-341a82ad9727.png
# epoch = 00000336, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/862a8d2c-b6f3-46d1-9ae2-2438e8d05ef8.png
# epoch = 00000337, time = 0.103, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/72e23f89-fcbf-4ee6-84e4-a8ce72c8e44c.png
# epoch = 00000338, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b4f453c2-6360-4fe0-8b65-19dd5c69dfa5.png
# epoch = 00000339, time = 0.102, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6e3da2da-fd82-4261-bcc4-a0326ebdce66.png
# epoch = 00000340, time = 0.103, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/6c853830-9889-4e26-8b65-a139687ea482.png
# epoch = 00000341, time = 0.101, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/aca86f27-3b86-426f-9016-04ceeea096af.png
# epoch = 00000342, time = 0.104, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/0a7a1ce1-7b4a-4c20-a369-f118522f8bf4.png
# ...
# epoch = 00003883, time = 0.268, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/2624b2d9-0039-4a23-a73f-5743ae4b09ce.png
# epoch = 00003884, time = 0.262, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/d178e9bd-615f-4432-b089-f2c708616085.png
# epoch = 00003885, time = 0.282, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/bd107562-dcd8-48ab-aa23-1b069e58e75b.png
# epoch = 00003886, time = 0.282, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/532c67dc-7b6f-41ae-be37-19c22bb9109b.png
# epoch = 00003887, time = 0.273, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6dd96beb-368c-456c-93d0-8cfb07224360.png
# epoch = 00003888, time = 0.296, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/cd7b9d92-6c32-4e74-9ec5-a9f44d39eab9.png
# epoch = 00003889, time = 0.287, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a28284b6-14cb-4c1b-bde2-bc3e0ce56508.png
# epoch = 00003890, time = 0.287, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/7d8fe950-a643-4436-9b41-da61d35b3714.png
# epoch = 00003891, time = 0.285, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0676f2a4-93ec-4f8b-99d2-cb73e448f6b2.png
# epoch = 00003892, time = 0.300, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/1f108a5c-4cc2-45ad-acfe-b159ebfeb8f4.png
# epoch = 00003893, time = 0.278, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/728164fc-08ca-48fb-ba1c-e6aba4225eda.png
# epoch = 00003894, time = 0.315, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/b6c69490-c7ce-471b-8a84-ea82f8180405.png
# epoch = 00003895, time = 0.273, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/ea98c90b-1ad5-49a4-8974-2393a5126054.png
# epoch = 00003896, time = 0.287, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/16c78d71-7849-44de-95f6-cb86604c0071.png
# epoch = 00003897, time = 0.274, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/b2647d9f-9bfb-446a-9605-c223cbd0878d.png
# epoch = 00003898, time = 0.287, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/afda1dc2-c1c0-425a-91a8-339d5e340457.png
# epoch = 00003899, time = 0.261, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/643820ef-4dc3-4120-99e0-27a0142ac578.png
# epoch = 00003900, time = 0.307, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\DOWN/fb3c98bd-2c65-4fc3-8fc8-62808efe8f29.png
# epoch = 00003901, time = 0.283, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/1196b988-dc50-406f-a669-af8f3eb92d2e.png
# epoch = 00003902, time = 0.270, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/574d58b3-d259-453a-a680-58b7ed9456d0.png
# epoch = 00003903, time = 0.274, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/29d4275a-156d-4976-b9b5-bccf001adcc9.png
# epoch = 00003904, time = 0.289, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/39702ee4-8475-423f-865c-3103e24c6b20.png
# epoch = 00003905, time = 0.274, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/9af63f71-c03d-4139-baad-11fe1795620c.png
# epoch = 00003906, time = 0.272, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/e26900ce-3599-437b-8ec6-22db5412b869.png
# epoch = 00003907, time = 0.264, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/01abaf0f-ca36-4687-b73d-b1fde71a2374.png
# epoch = 00003908, time = 0.318, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/0114183b-7b07-462d-91fc-5c31bcb4d219.png
# epoch = 00003909, time = 0.313, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/976a630e-b32d-4ed3-960b-ec1174bd84e2.png
# epoch = 00003910, time = 0.292, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/d43498cb-4914-4ba9-9ed2-a054c26beba0.png
# epoch = 00003911, time = 0.289, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1a05716e-0d68-4331-ab60-51561fb93822.png
# epoch = 00003912, time = 0.313, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/42a2f069-b179-4684-bb17-6560e9b89d39.png
# epoch = 00003913, time = 0.321, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/1da58ec2-9842-4094-9183-fc49844d244e.png
# epoch = 00003914, time = 0.281, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f2be8050-2634-466f-8f0d-07cc37d492ba.png
# epoch = 00003915, time = 0.277, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/0216558d-6298-45e6-8418-98b7346011dd.png
# epoch = 00003916, time = 0.290, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/06f58dc1-f594-4627-9f9e-714a8ffd2c86.png
# epoch = 00003917, time = 0.269, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/6583bd09-0e68-402d-a836-9575e7e2a501.png
# epoch = 00003918, time = 0.284, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b2a22841-fdd7-424b-a7dd-5d4549bf9114.png
# epoch = 00003919, time = 0.263, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/8f7746e0-99d2-4736-9e4e-aab6a07a2251.png
# epoch = 00003920, time = 0.297, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/7cb16206-e213-423d-8145-b85b35555f24.png
# epoch = 00003921, time = 0.279, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ebb844f8-8b8c-4c0f-8a55-b5ac73beadd1.png
# epoch = 00003922, time = 0.571, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/44023913-dd85-4ee8-9582-146f68b6e9ce.png
# epoch = 00003923, time = 0.541, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/ef922b49-1d1a-46a1-9a53-e9e7999d8005.png
# epoch = 00003924, time = 0.286, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/bf71db0d-0b56-4d08-b8aa-6f2630efa9f5.png
# epoch = 00003925, time = 0.295, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/f9a86a42-4fdd-46df-9cf8-aedad42f57a6.png
# epoch = 00003926, time = 0.281, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/f68c3b1d-f9ee-4da2-aa48-265eda986eb6.png
# epoch = 00003927, time = 0.277, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/6e502f91-952d-4f9f-b026-453c6df9f67a.png
# epoch = 00003928, time = 0.322, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/70e17dec-610b-4665-82ed-4d1c1a14b7f4.png
# epoch = 00003929, time = 0.250, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/69a00816-1d35-447f-9b9b-6028cdbaa3e2.png
# epoch = 00003930, time = 0.283, filename = D:\Git Repository\_local_data_\DLW\TA CNN\test\UP/5ccae62a-926a-4e80-90b2-39d725301140.png
# epoch = 00003931, time = 0.266, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c0afebc0-df33-4360-80c0-e0b781a502d6.png
# epoch = 00003932, time = 0.298, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/a61b39f9-5c0c-42a5-8cc2-286cf33f804e.png
# epoch = 00003933, time = 0.277, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/b0d3aae4-a3dd-47ee-aabe-3a98ae80cc62.png
# epoch = 00003934, time = 0.286, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\DOWN/c44f719f-2058-4f2b-8ff8-d529d327e577.png
# epoch = 00003935, time = 0.282, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/227012b1-3a49-4b3b-a51a-7bd9223a8e82.png
# epoch = 00003936, time = 0.274, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP/a3f5f242-2317-4fe8-9692-28f7bfafdc94.png
# epoch = 00003937, time = 0.284, filename = D:\Git Repository\_local_data_\DLW\TA CNN\train\UP